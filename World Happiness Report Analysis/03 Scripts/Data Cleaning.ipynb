# %% [markdown]
# ## This script contains:
# #### 01. Import libraries
# #### 02. Import data
# #### 03. Explore data
# #### 04. Missing values
# #### 05. Duplicate values
# #### 06. Make columns uniform
# #### 07. Combine data sets
# #### 08. Export data

# %% [markdown]
# # 01. Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data

# %%
# create path to folder

path = r'C:\Users\ejgor\OneDrive\Data Analytics\Data Immersion\Achievement 6 - Advanced Analytics & Dashboard Design\World Happiness Report Analysis'

# %%
# import dataframes

df1 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2015.csv'), index_col = False)
df2 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2016.csv'), index_col = False)
df3 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2017.csv'), index_col = False)
df4 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2018.csv'), index_col = False)
df5 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2019.csv'), index_col = False)

# %% [markdown]
# # 03. Explore data

# %% [markdown]
# ## 2015

# %%
df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df1.shape
# Out:
# (158, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df1.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# ## 2016

# %%
df2.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df2.shape
# Out:
# (157, 13)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
df2.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %% [markdown]
# ## 2017

# %%
df3.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df3.shape
# Out:
# (155, 12)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
df3.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %% [markdown]
# ## 2018

# %%
df4.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df4.shape
# Out:
# (156, 9)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df4.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# ## 2019

# %%
df5.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df5.shape
# Out:
# (156, 9)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df5.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# #### All datasets have the following columns: Rank, Country, Score, GDP, Support, Health, Freedom, Generosity, and Corruption. All other columns will be removed and placed in the same order to make columns uniform to use pd.concat.

# %% [markdown]
# # 04. Missing values

# %%
# 2015

df1.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# 2016

df2.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# 2017

df3.isnull().sum()
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
# 2018

df4.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
# 2019

df5.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# ### 1 missing value in 2018 - 'Perceptions of corruption'

# %% [markdown]
# # 05. Duplicate values

# %%
# 2015

df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
# 2016

df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
# 2017

df3[df3.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %%
# 2018

df4[df4.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# 2019

df5[df5.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# ### No duplicates in any data set

# %% [markdown]
# # 06. Make columns uniform

# %% [markdown]
# ## 2015

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
usecols = ['Rank','Country','Score','GDP','Support',
                'Health','Freedom','Generosity','Corruption']

# %%
df1.drop(['Region','Standard Error', 'Dystopia Residual'],axis=1,inplace=True)

# %%
df1.columns = ['Country','Rank','Score','Support','GDP','Health','Freedom','Generosity','Corruption']

# %%
# add year column

df1['Year'] = 2015

# %%
df1.head()
# Out:
#        Country  Rank  Score  Support      GDP   Health  Freedom  Generosity  \
# 0  Switzerland     1  7.587  1.39651  1.34951  0.94143  0.66557     0.41978
# 1      Iceland     2  7.561  1.30232  1.40223  0.94784  0.62877     0.14145
# 2      Denmark     3  7.527  1.32548  1.36058  0.87464  0.64938     0.48357
# 3       Norway     4  7.522  1.45900  1.33095  0.88521  0.66973     0.36503
# 4       Canada     5  7.427  1.32629  1.32261  0.90563  0.63297     0.32957
#
#    Corruption  Year
# 0     0.29678  2015
# 1     0.43630  2015
# 2     0.34139  2015
# 3     0.34699  2015
# 4     0.45811  2015

# %% [markdown]
# ## 2016

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
usecols = ['Rank','Country','Score','GDP','Support',
                'Health','Freedom','Generosity','Corruption']

# %%
df2.drop(['Region','Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual'],axis=1,inplace=True)

# %%
df2.columns = ['Country','Rank','Score','Support','GDP','Health','Freedom','Generosity','Corruption']

# %%
# add year column

df2['Year'] = 2016

# %%
df2.head()
# Out:
#        Country  Rank  Score  Support      GDP   Health  Freedom  Generosity  \
# 0      Denmark     1  7.526  1.44178  1.16374  0.79504  0.57941     0.44453
# 1  Switzerland     2  7.509  1.52733  1.14524  0.86303  0.58557     0.41203
# 2      Iceland     3  7.501  1.42666  1.18326  0.86733  0.56624     0.14975
# 3       Norway     4  7.498  1.57744  1.12690  0.79579  0.59609     0.35776
# 4      Finland     5  7.413  1.40598  1.13464  0.81091  0.57104     0.41004
#
#    Corruption  Year
# 0     0.36171  2016
# 1     0.28083  2016
# 2     0.47678  2016
# 3     0.37895  2016
# 4     0.25492  2016

# %% [markdown]
# ## 2017

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
usecols = ['Rank','Country','Score','GDP','Support',
                'Health','Freedom','Generosity','Corruption']

# %%
df3.drop(['Whisker.high', 'Whisker.low', 'Dystopia.Residual'],axis=1,inplace=True)

# %%
df3.columns = ['Country','Rank','Score','Support','GDP','Health','Freedom','Generosity','Corruption']

# %%
# add year column

df3['Year'] = 2017

# %%
df3.head()
# Out:
#        Country  Rank  Score   Support       GDP    Health   Freedom  \
# 0       Norway     1  7.537  1.616463  1.533524  0.796667  0.635423
# 1      Denmark     2  7.522  1.482383  1.551122  0.792566  0.626007
# 2      Iceland     3  7.504  1.480633  1.610574  0.833552  0.627163
# 3  Switzerland     4  7.494  1.564980  1.516912  0.858131  0.620071
# 4      Finland     5  7.469  1.443572  1.540247  0.809158  0.617951
#
#    Generosity  Corruption  Year
# 0    0.362012    0.315964  2017
# 1    0.355280    0.400770  2017
# 2    0.475540    0.153527  2017
# 3    0.290549    0.367007  2017
# 4    0.245483    0.382612  2017

# %% [markdown]
# ## 2018

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
usecols = ['Rank','Country','Score','GDP','Support',
                'Health','Freedom','Generosity','Corruption']

# %%
# shift column 'Country' to first position

first_column = df4.pop('Country or region')

#insert column

df4.insert(0, 'Country or region', first_column)

# %%
df4.columns = ['Country','Rank','Score','Support','GDP','Health','Freedom','Generosity','Corruption']

# %%
# add year column

df4['Year'] = 2018

# %%
df4.head()
# Out:
#        Country  Rank  Score  Support    GDP  Health  Freedom  Generosity  \
# 0      Finland     1  7.632    1.305  1.592   0.874    0.681       0.202
# 1       Norway     2  7.594    1.456  1.582   0.861    0.686       0.286
# 2      Denmark     3  7.555    1.351  1.590   0.868    0.683       0.284
# 3      Iceland     4  7.495    1.343  1.644   0.914    0.677       0.353
# 4  Switzerland     5  7.487    1.420  1.549   0.927    0.660       0.256
#
#    Corruption  Year
# 0       0.393  2018
# 1       0.340  2018
# 2       0.408  2018
# 3       0.138  2018
# 4       0.357  2018

# %% [markdown]
# ## 2019

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
usecols = ['Rank','Country','Score','GDP','Support',
                'Health','Freedom','Generosity','Corruption']

# %%
# shift column 'Country' to first position

first_column = df5.pop('Country or region')

#insert column

df5.insert(0, 'Country or region', first_column)

# %%
df5.columns = ['Country','Rank','Score','Support','GDP','Health','Freedom','Generosity','Corruption']

# %%
# add year column

df5['Year'] = 2019

# %%
df5.head()
# Out:
#        Country  Rank  Score  Support    GDP  Health  Freedom  Generosity  \
# 0      Finland     1  7.769    1.340  1.587   0.986    0.596       0.153
# 1      Denmark     2  7.600    1.383  1.573   0.996    0.592       0.252
# 2       Norway     3  7.554    1.488  1.582   1.028    0.603       0.271
# 3      Iceland     4  7.494    1.380  1.624   1.026    0.591       0.354
# 4  Netherlands     5  7.488    1.396  1.522   0.999    0.557       0.322
#
#    Corruption  Year
# 0       0.393  2019
# 1       0.410  2019
# 2       0.341  2019
# 3       0.118  2019
# 4       0.298  2019

# %% [markdown]
# # 07. Combine data sets

# %%
df1.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'Support', 'GDP', 'Health', 'Freedom',
#        'Generosity', 'Corruption', 'Year'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'Support', 'GDP', 'Health', 'Freedom',
#        'Generosity', 'Corruption', 'Year'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'Support', 'GDP', 'Health', 'Freedom',
#        'Generosity', 'Corruption', 'Year'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'Support', 'GDP', 'Health', 'Freedom',
#        'Generosity', 'Corruption', 'Year'],
#       dtype='object')

# %%
df5.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'Support', 'GDP', 'Health', 'Freedom',
#        'Generosity', 'Corruption', 'Year'],
#       dtype='object')

# %%
# concat all data sets together

frames = [df1, df2, df3, df4, df5]
df_all = pd.concat(frames)

# %%
# check for missing data

df_all.isnull().any()
# Out:
# Country       False
# Rank          False
# Score         False
# Support       False
# GDP           False
# Health        False
# Freedom       False
# Generosity    False
# Corruption     True
# Year          False
# dtype: bool

# %%
# filling missing values of 'Corruption' with its mean

df_all.Corruption.fillna((df_all.Corruption.mean()), inplace = True)

# %%
# check for missing data

df_all.isnull().any()
# Out:
# Country       False
# Rank          False
# Score         False
# Support       False
# GDP           False
# Health        False
# Freedom       False
# Generosity    False
# Corruption    False
# Year          False
# dtype: bool

# %%
df_all.head(10)
# Out:
#        Country  Rank  Score  Support      GDP   Health  Freedom  Generosity  \
# 0  Switzerland     1  7.587  1.39651  1.34951  0.94143  0.66557     0.41978
# 1      Iceland     2  7.561  1.30232  1.40223  0.94784  0.62877     0.14145
# 2      Denmark     3  7.527  1.32548  1.36058  0.87464  0.64938     0.48357
# 3       Norway     4  7.522  1.45900  1.33095  0.88521  0.66973     0.36503
# 4       Canada     5  7.427  1.32629  1.32261  0.90563  0.63297     0.32957
# 5      Finland     6  7.406  1.29025  1.31826  0.88911  0.64169     0.41372
# 6  Netherlands     7  7.378  1.32944  1.28017  0.89284  0.61576     0.31814
# 7       Sweden     8  7.364  1.33171  1.28907  0.91087  0.65980     0.43844
# 8  New Zealand     9  7.286  1.25018  1.31967  0.90837  0.63938     0.42922
# 9    Australia    10  7.284  1.33358  1.30923  0.93156  0.65124     0.35637
#
#    Corruption  Year
# 0     0.29678  2015
# 1     0.43630  2015
# 2     0.34139  2015
# 3     0.34699  2015
# 4     0.45811  2015
# ...

# %%
df_all.tail(10)
# Out:
#                       Country  Rank  Score  Support    GDP  Health  Freedom  \
# 146                     Haiti   147  3.597    0.323  0.688   0.449    0.026
# 147                  Botswana   148  3.488    1.041  1.145   0.538    0.455
# 148                     Syria   149  3.462    0.619  0.378   0.440    0.013
# 149                    Malawi   150  3.410    0.191  0.560   0.495    0.443
# 150                     Yemen   151  3.380    0.287  1.163   0.463    0.143
# 151                    Rwanda   152  3.334    0.359  0.711   0.614    0.555
# 152                  Tanzania   153  3.231    0.476  0.885   0.499    0.417
# 153               Afghanistan   154  3.203    0.350  0.517   0.361    0.000
# 154  Central African Republic   155  3.083    0.026  0.000   0.105    0.225
# 155               South Sudan   156  2.853    0.306  0.575   0.295    0.010
#
#      Generosity  Corruption  Year
# 146       0.419       0.110  2019
# 147       0.025       0.100  2019
# ...

# %%
df_all.describe()
# Out:
#              Rank       Score     Support         GDP      Health     Freedom  \
# count  782.000000  782.000000  782.000000  782.000000  782.000000  782.000000
# mean    78.698210    5.379018    0.916047    1.078392    0.612416    0.411091
# std     45.182384    1.127456    0.407340    0.329548    0.248309    0.152880
# min      1.000000    2.693000    0.000000    0.000000    0.000000    0.000000
# 25%     40.000000    4.509750    0.606500    0.869363    0.440183    0.309768
# 50%     79.000000    5.322000    0.982205    1.124735    0.647310    0.431000
# 75%    118.000000    6.189500    1.236187    1.327250    0.808000    0.531000
# max    158.000000    7.769000    2.096000    1.644000    1.141000    0.724000
#
#        Generosity  Corruption         Year
# count  782.000000  782.000000   782.000000
# mean     0.178526    0.165536  2016.993606
# std      0.119115    0.127329     1.417364
# min      0.000000    0.000000  2015.000000
# 25%      0.084860    0.067921  2016.000000
# ...

# %% [markdown]
# # 08. Export data

# %%
# export df_all

df_all.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'WHR_2015-2019.csv'), index = False)
